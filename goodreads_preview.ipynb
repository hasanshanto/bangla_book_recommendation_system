# %%
import pandas as pd

# %%
import json

# %%
with open("goodreads.json") as datafile:
  gr = json.load(datafile)
df = pd.DataFrame(gr)

# %%
df
# Out:
#          isbn text_reviews_count series country_code language_code  \
# 0  0312853122                  1     []           US
# 1  0743509986                  6     []           US
#
#                                      popular_shelves asin is_ebook  \
# 0  [{'count': '3', 'name': 'to-read'}, {'count': ...         false
# 1  [{'count': '2634', 'name': 'to-read'}, {'count...         false
#
#   average_rating kindle_asin  ... publication_month edition_information  \
# 0           4.00              ...                 9
# 1           3.23  B000FC0PBC  ...                10            Abridged
#
#   publication_year                                                url  \
# 0             1984  https://www.goodreads.com/book/show/5333265-w-...
# 1             2001  https://www.goodreads.com/book/show/1333909.Go...
#
#                                            image_url  book_id ratings_count  \
# 0  https://images.gr-assets.com/books/1310220028m...  5333265             3
# ...

# %%
df.describe()
# Out:
#               isbn text_reviews_count series country_code language_code  \
# count            2                  2      2            2             2
# unique           2                  2      1            1             1
# top     0312853122                  1     []           US
# freq             1                  1      2            2             2
#
#                                           popular_shelves asin is_ebook  \
# count                                                   2    2        2
# unique                                                  2    1        1
# top     [{'count': '3', 'name': 'to-read'}, {'count': ...         false
# freq                                                    1    2        2
#
#        average_rating kindle_asin  ... publication_month edition_information  \
# count               2           2  ...                 2                   2
# unique              2           2  ...                 2                   2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   isbn                  2 non-null      object
#  1   text_reviews_count    2 non-null      object
#  2   series                2 non-null      object
#  3   country_code          2 non-null      object
#  4   language_code         2 non-null      object
#  5   popular_shelves       2 non-null      object
#  6   asin                  2 non-null      object
#  7   is_ebook              2 non-null      object
#  8   average_rating        2 non-null      object
#  9   kindle_asin           2 non-null      object
#  10  similar_books         2 non-null      object
#  11  description           2 non-null      object
#  12  format                2 non-null      object
#  13  link                  2 non-null      object
#  14  authors               2 non-null      object
# ...
